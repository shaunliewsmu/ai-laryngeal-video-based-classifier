# %% [markdown]
# # Fine-tuning for Video Classification with 🤗 Transformers using ViViT
# ### Abstract for ViViT
# We present pure-transformer based models for video classification, drawing upon the recent success of such models in image classification. Our model extracts spatio-temporal tokens from the input video, which are then encoded by a series of transformer layers. In order to handle the long sequences of tokens encountered in video, we propose several, efficient variants of our model which factorise the spatial- and temporal-dimensions of the input. Although transformer-based models are known to only be effective when large training datasets are available, we show how we can effectively regularise the model during training and leverage pretrained image models to be able to train on comparatively small datasets. We conduct thorough ablation studies, and achieve state-of-the-art results on multiple video classification benchmarks including Kinetics 400 and 600, Epic Kitchens, Something-Something v2 and Moments in Time, outperforming prior methods based on deep 3D convolutional networks. To facilitate further research, we release code at https://github.com/google-research/scenic/tree/main/scenic/projects/vivit
#
# https://arxiv.org/pdf/2103.15691
#
# ## Embeddings
# ### Uniform frame sampling
# straightforward method of tokenising the input video is to uniformly sample nt frames from the input video clip, embed each 2D frame independently using the same method as ViT, and concatenate all these tokens together. Concretely, if nh · nw non-overlapping image patches are extracted from each frame, then a total of nt ·nh·nw tokens will be forwarded through the transformer encoder.Intuitively, this process may be seen as simply constructing a large 2D image to be tokenised following ViT
#
# #### Tubelet embedding
# An alternate method, to extract non-overlapping, spatio-temporal “tubes” from the input volume, and to linearly project this to Rd. This method is an extension of ViT’s embedding to 3D,and corresponds to a 3D convolution.
#
# ### HF Vivit
# https://huggingface.co/docs/transformers/main/model_doc/vivit
#
# # Pretrained Dataset
# https://paperswithcode.com/dataset/kinetics-400-1
#
# # Base Model
#
# https://github.com/google-research/scenic/tree/main/scenic/projects/vivit
#
# ### google/vivit-f-16x2-kinetics400
#
# ##### https://huggingface.co/docs/transformers/main/model_doc/vivit
#
# ## Fine tune the model using the Duke Dataset

# %% [markdown]
# ## Load the dataset artifacts from wandb
#
# make sure you have created a [wandb](https://wandb.ai/site/) account.

# %%
import wandb

# %%
# Initialize wandb
# import os
# wandb_key =  os.getenv("WANDB_API_KEY")
# wandb.login(key=wandb_key)
MODEL_NAME = "google/vivit-b-16x2-kinetics400"
DATASET = "duke iqm yolov5 filtered dataset"
PROJECT = "laryngeal_cancer_video_classification"

# %%
run = wandb.init(
    project=PROJECT,
    name="vivit-b-16x2-training-iqm-filtered", # runs process name
    tags=[MODEL_NAME, DATASET],
    entity="shaunliewsmu-singapore-management-university"
)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>/home/shaunliew/ai-laryngeal-video-based-classifier/wandb/run-20250205_161149-1k1064eq</code>
# Syncing run <strong><a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/1k1064eq' target="_blank">vivit-b-16x2-training-iqm-filtered</a></strong> to <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a>
#  View run at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/1k1064eq' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/1k1064eq</a>

# %%
# Access the dataset through registry name
artifact = run.use_artifact('laryngeal_cancer_video_classification/laryngeal_dataset_iqm_filtered:v0')
dataset_dir = artifact.download()
print(f"\nSuccessfully downloaded dataset to {dataset_dir}")

# Print artifact metadata if available
if hasattr(artifact, 'metadata'):
    print("\nArtifact metadata:")
    for key, value in artifact.metadata.items():
        print(f"{key}: {value}")
# Out:
# wandb: Downloading large artifact laryngeal_dataset_iqm_filtered:v0, 648.15MB. 133 files...
# wandb:   133 of 133 files downloaded.
# Done. 0:0:0.7
# Successfully downloaded dataset to /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0
#
# Artifact metadata:
# total_videos: 132
# referral_ratio: 66.67%
# total_referral: 88
# dataset_structure: {'val': {'total': 20, 'referral': 14, 'non_referral': 6, 'referral_ratio': '70.00%', 'non_referral_ratio': '30.00%'}, 'test': {'total': 20, 'referral': 13, 'non_referral': 7, 'referral_ratio': '65.00%', 'non_referral_ratio': '35.00%'}, 'train': {'total': 92, 'referral': 61, 'non_referral': 31, 'referral_ratio': '66.30%', 'non_referral_ratio': '33.70%'}}
# total_non_referral: 44

# %%
from transformers import TrainingArguments
from transformers import Trainer, TrainingArguments
from data_preprocessing import create_dataset
from data_handling import frames_convert_and_create_dataset_dictionary

# %%
from dotenv import load_dotenv
env_path =  ".env"
load_dotenv(env_path)
# Out:
# True

# %% [markdown]
# # Data Preprocessing

# %%
import model_configuration
from model_configuration import compute_metrics,collate_fn
import av
import numpy as np
from data_handling import sample_frame_indices, read_video_pyav

# %%
video_path = "/home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0057_processed.mp4"
container = av.open(video_path)

# %%
container.streams.video[0].frames
# Out:
# 59

# %%
from moviepy import *

# %%
container = av.open(video_path)
indices = sample_frame_indices(clip_len=10, frame_sample_rate=2,seg_len=container.streams.video[0].frames)
video = read_video_pyav(container=container, indices=indices)
# Out:
# Reading frames from 26 to 45
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)

# %%
indices
# Out:
# array([26, 28, 30, 32, 34, 37, 39, 41, 43, 45])

# %%
video.shape
# Out:
# (10, 224, 224, 3)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
path_files = "artifacts/laryngeal_dataset_iqm_filtered:v0"
video_dict, class_labels = frames_convert_and_create_dataset_dictionary(path_files)
# Out:
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0165_processed.mp4 number of Frames: 509
# Reading frames from 136 to 145
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0030_processed.mp4 number of Frames: 40
# Reading frames from 29 to 38
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0197_processed.mp4 number of Frames: 32
# Reading frames from 4 to 13
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0090_processed.mp4 number of Frames: 64
# Reading frames from 32 to 41
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0157_processed.mp4 number of Frames: 100
# Reading frames from 50 to 59
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0212_processed.mp4 number of Frames: 3
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0212_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0208_processed.mp4 number of Frames: 5
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0208_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0025_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0025_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0225_processed.mp4 number of Frames: 75
# Reading frames from 43 to 52
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0152_processed.mp4 number of Frames: 282
# Reading frames from 151 to 160
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0101_processed.mp4 number of Frames: 65
# Reading frames from 14 to 23
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0187_processed.mp4 number of Frames: 508
# Reading frames from 314 to 323
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0195_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0195_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0012_processed.mp4 number of Frames: 2
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0012_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0135_processed.mp4 number of Frames: 6
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0135_processed.mp4: low >= high
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0171_processed.mp4: tuple index out of range
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0106_processed.mp4 number of Frames: 709
# Reading frames from 373 to 382
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0099_processed.mp4 number of Frames: 4
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0099_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0174_processed.mp4 number of Frames: 357
# Reading frames from 159 to 168
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0192_processed.mp4 number of Frames: 3
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0192_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0109_processed.mp4 number of Frames: 22
# Reading frames from 7 to 16
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0105_processed.mp4 number of Frames: 246
# Reading frames from 232 to 241
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0156_processed.mp4 number of Frames: 18
# Reading frames from 3 to 12
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0188_processed.mp4 number of Frames: 8
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0188_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0093_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0093_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0216_processed.mp4 number of Frames: 29
# Reading frames from 16 to 25
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0186_processed.mp4 number of Frames: 93
# Reading frames from 61 to 70
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/0037_processed.mp4 number of Frames: 20
# Reading frames from 0 to 9
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/referral/
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0063_processed.mp4 number of Frames: 19
# Reading frames from 0 to 9
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0066_processed.mp4 number of Frames: 153
# Reading frames from 123 to 132
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0169_processed.mp4 number of Frames: 112
# Reading frames from 58 to 67
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0042_processed.mp4 number of Frames: 63
# Reading frames from 5 to 14
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0041_processed.mp4 number of Frames: 31
# Reading frames from 15 to 24
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0209_processed.mp4 number of Frames: 15
# Reading frames from 4 to 13
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/train/non_referral/0079_processed.mp4 number of Frames: 58
# Reading frames from 2 to 11
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0131_processed.mp4 number of Frames: 12
# Reading frames from 1 to 10
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0071_processed.mp4 number of Frames: 6
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0071_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0060_processed.mp4 number of Frames: 33
# Reading frames from 3 to 12
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0202_processed.mp4 number of Frames: 67
# Reading frames from 18 to 27
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0057_processed.mp4 number of Frames: 59
# Reading frames from 25 to 34
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0125_processed.mp4 number of Frames: 1626
# Reading frames from 1534 to 1543
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0097_processed.mp4 number of Frames: 112
# Reading frames from 18 to 27
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0116_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0116_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0074_processed.mp4 number of Frames: 293
# Reading frames from 147 to 156
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0076_processed.mp4 number of Frames: 35
# Reading frames from 6 to 15
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0207_processed.mp4: tuple index out of range
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0173_processed.mp4 number of Frames: 248
# Reading frames from 51 to 60
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/referral/0148_processed.mp4 number of Frames: 1359
# Reading frames from 488 to 497
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0219_processed.mp4 number of Frames: 135
# Reading frames from 32 to 41
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0167_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0167_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0056_processed.mp4 number of Frames: 13
# Reading frames from 2 to 11
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0052_processed.mp4: tuple index out of range
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0110_processed.mp4 number of Frames: 82
# Reading frames from 0 to 9
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0136_processed.mp4 number of Frames: 438
# Reading frames from 266 to 275
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/test/non_referral/0023_processed.mp4 number of Frames: 71
# Reading frames from 27 to 36
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0081_processed.mp4 number of Frames: 19
# Reading frames from 8 to 17
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0224_processed.mp4 number of Frames: 459
# Reading frames from 433 to 442
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0039_processed.mp4 number of Frames: 27
# Reading frames from 9 to 18
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0128_processed.mp4 number of Frames: 5
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0128_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0098_processed.mp4 number of Frames: 1
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0098_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0047_processed.mp4 number of Frames: 24
# Reading frames from 2 to 11
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0201_processed.mp4 number of Frames: 7
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0201_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0088_processed.mp4 number of Frames: 168
# Reading frames from 6 to 15
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0094_processed.mp4 number of Frames: 61
# Reading frames from 15 to 24
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0153_processed.mp4 number of Frames: 116
# Reading frames from 89 to 98
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0220_processed.mp4 number of Frames: 16
# Reading frames from 0 to 9
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0168_processed.mp4 number of Frames: 15
# Reading frames from 3 to 12
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0124_processed.mp4 number of Frames: 68
# Reading frames from 48 to 57
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0149_processed.mp4 number of Frames: 240
# Reading frames from 1 to 10
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0151_processed.mp4 number of Frames: 7
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0151_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0180_processed.mp4 number of Frames: 195
# Reading frames from 128 to 137
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0150_processed.mp4 number of Frames: 627
# Reading frames from 303 to 312
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0223_processed.mp4 number of Frames: 2
# Error processing artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0223_processed.mp4: low >= high
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0146_processed.mp4 number of Frames: 20
# Reading frames from 4 to 13
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0031_processed.mp4 number of Frames: 459
# Reading frames from 36 to 45
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Min number frames 12

# %%
len(video_dict)
# Out:
# 95

# %%
video_dict[0].keys()
# Out:
# dict_keys(['video', 'labels', 'split', 'path'])

# %%
video_dict[0]['video'].shape
# Out:
# (10, 224, 224, 3)

# %%
video_dict[0]['labels']
# Out:
# 'referral'

# %%
num_frames, height, width, channels =  video_dict[0]['video'].shape
num_frames, height, width, channels
# Out:
# (10, 224, 224, 3)

# %% [markdown]
# # Display Video sample

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML

def display_video_sample(video_sample):
    """
    Display a video sample using matplotlib animation
    """
    # Get frames from the sample
    frames = video_sample['video']
    
    # Create figure and axes
    fig, ax = plt.subplots(figsize=(8, 8))
    plt.close() # Prevents displaying the empty figure
    
    # Remove axes
    ax.set_xticks([])
    ax.set_yticks([])
    
    # Display first frame
    img = ax.imshow(frames[0])
    
    def animate(i):
        img.set_array(frames[i])
        return (img,)
    
    # Create animation
    anim = animation.FuncAnimation(
        fig, 
        animate, 
        frames=len(frames),
        interval=100,  # Time between frames in milliseconds
        blit=True
    )
    
    # Display the animation
    return HTML(anim.to_jshtml())

# %%
# Display a sample video
sample_video = video_dict[0]
print(f"Displaying video with label: {sample_video['labels']}")
display_video_sample(sample_video)
# Out:
# Displaying video with label: referral
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img21df9ce1b6364154bba553b8ce5a9dc3">
#   <div class="anim-controls">
#     <input id="_anim_slider21df9ce1b6364154bba553b8ce5a9dc3" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim21df9ce1b6364154bba553b8ce5a9dc3.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim21df9ce1b6364154bba553b8ce5a9dc3.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select21df9ce1b6364154bba553b8ce5a9dc3"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_21df9ce1b6364154bba553b8ce5a9dc3"
#              >
#       <label for="_anim_radio1_21df9ce1b6364154bba553b8ce5a9dc3">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_21df9ce1b6364154bba553b8ce5a9dc3"
#              checked>
#       <label for="_anim_radio2_21df9ce1b6364154bba553b8ce5a9dc3">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_21df9ce1b6364154bba553b8ce5a9dc3"
#              >
#       <label for="_anim_radio3_21df9ce1b6364154bba553b8ce5a9dc3">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img21df9ce1b6364154bba553b8ce5a9dc3";
#     var slider_id = "_anim_slider21df9ce1b6364154bba553b8ce5a9dc3";
#     var loop_select_id = "_anim_loop_select21df9ce1b6364154bba553b8ce5a9dc3";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJR

# %%
class_labels = sorted(class_labels)
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}

print(f"Unique classes: {list(label2id.keys())}.")
# Out:
# Unique classes: ['non_referral', 'referral'].

# %%
print("\nChecking input video format:")
first_video = video_dict[0]
print("Input video shape:", np.array(first_video['video']).shape)
print("Input video type:", type(first_video['video']))
# Out:
# Checking input video format:
# Input video shape: (10, 224, 224, 3)
# Input video type: <class 'numpy.ndarray'>

# %%
shuffled_dataset = create_dataset(video_dict)
# Out:
# Casting to class labels: 100%|██████████| 95/95 [00:00<00:00, 326.63 examples/s]
# Processing videos: 100%|██████████| 95/95 [02:50<00:00,  1.80s/ examples]
# First sample structure:
# Keys: dict_keys(['labels', 'split', 'path', 'pixel_values'])
# Pixel values type: <class 'list'>

# %%
shuffled_dataset['train'].features
# Out:
# {'labels': ClassLabel(names=['non_referral', 'referral'], id=None),
#  'split': Value(dtype='string', id=None),
#  'path': Value(dtype='string', id=None),
#  'pixel_values': Sequence(feature=Sequence(feature=Sequence(feature=Sequence(feature=Value(dtype='float32', id=None), length=-1, id=None), length=-1, id=None), length=-1, id=None), length=-1, id=None)}

# %%
# Debug prints
print("\nChecking processed dataset:")
print("Dataset size:", len(shuffled_dataset['train']))

sample = shuffled_dataset['train'][0]
print("\nSample inspection:")
print("Sample keys:", sample.keys())
print("Sample pixel values type:", type(sample['pixel_values']))
if isinstance(sample['pixel_values'], torch.Tensor):
    print("Sample pixel values shape:", sample['pixel_values'].shape)
print("Sample label:", sample['labels'])

# Test batch creation
print("\nTesting batch creation:")
batch = collate_fn([shuffled_dataset['train'][i] for i in range(2)])
print("Batch pixel values shape:", batch['pixel_values'].shape)
print("Batch labels shape:", batch['labels'].shape)
# Out:
# Checking processed dataset:
# Dataset size: 85
#
# Sample inspection:
# Sample keys: dict_keys(['labels', 'split', 'path', 'pixel_values'])
# Sample pixel values type: <class 'list'>
# Sample label: 1
#
# Testing batch creation:
# Batch pixel values shape: torch.Size([2, 10, 3, 224, 224])
# Batch labels shape: torch.Size([2])

# %%
model = model_configuration.initialise_model(shuffled_dataset, device)
# Out:
# Some weights of VivitForVideoClassification were not initialized from the model checkpoint at google/vivit-b-16x2-kinetics400 and are newly initialized because the shapes did not match:
# - vivit.embeddings.position_embeddings: found shape torch.Size([1, 3137, 768]) in the checkpoint and torch.Size([1, 981, 768]) in the model instantiated
# - classifier.weight: found shape torch.Size([400, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([400]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from datetime import datetime

training_output_dir = "./training_results"
run_name = f"vivit-duke-iqm-filtered-{datetime.now().strftime('%Y%m%d-%H%M')}"

training_args = TrainingArguments(
    output_dir=training_output_dir,         
    num_train_epochs=40,             
    per_device_train_batch_size=8,   
    per_device_eval_batch_size=8,    
    learning_rate=5e-05,            
    weight_decay=0.01,              
    logging_dir="./logs",           
    logging_steps=10,                
    seed=42,                       
    eval_strategy="steps", 
    eval_steps=10,                   
    warmup_steps=int(0.1 * 20),      
    optim="adamw_torch",          
    lr_scheduler_type="linear",      
    fp16=True,  
    report_to="wandb",
    run_name=run_name
)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-05, betas=(0.9, 0.999), eps=1e-08)
# Define the trainer
trainer = Trainer(
    model=model,                      
    args=training_args,              
    train_dataset=shuffled_dataset["train"],      
    eval_dataset=shuffled_dataset["test"],       
    optimizers=(optimizer, None),  
    compute_metrics = compute_metrics,
    data_collator=collate_fn
)

# %%
with wandb.init(
    project=PROJECT, 
    job_type="train",
    name=run_name,  # Use same run name for consistency
    tags=[MODEL_NAME, DATASET],
    notes=f"Fine tuning {MODEL_NAME} with {DATASET}.",
    config={
        "model_name": MODEL_NAME,
        "dataset": DATASET,
        "batch_size": training_args.per_device_train_batch_size,
        "learning_rate": training_args.learning_rate,
        "num_epochs": training_args.num_train_epochs,
        "weight_decay": training_args.weight_decay
    }
) as run:
    train_results = trainer.train()
# Out:
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='240' max='240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [240/240 45:49, Epoch 40/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.639800</td>
#       <td>1.313759</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.430300</td>
#       <td>1.543230</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.208400</td>
#       <td>2.424440</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.102300</td>
#       <td>2.596303</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.024400</td>
#       <td>4.233907</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.002500</td>
#       <td>4.721967</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000100</td>
#       <td>5.144505</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000000</td>
#       <td>6.597664</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000000</td>
#       <td>10.422966</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000000</td>
#       <td>10.393098</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.000000</td>
#       <td>10.216352</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.000000</td>
#       <td>10.182434</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.000000</td>
#       <td>10.153275</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.000000</td>
#       <td>10.126275</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.000000</td>
#       <td>10.094824</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.000000</td>
#       <td>10.059387</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.000000</td>
#       <td>10.019209</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.000000</td>
#       <td>9.974546</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.000000</td>
#       <td>9.928802</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.000000</td>
#       <td>9.892702</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.000000</td>
#       <td>9.861984</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.000000</td>
#       <td>9.837929</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.000000</td>
#       <td>9.823495</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.000000</td>
#       <td>9.818472</td>
#       <td>0.400000</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /home/shaunliew/ai-laryngeal-video-based-classifier/venv/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▁▁▅▁▅▅█▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>eval/loss</td><td>▁▁▂▂▃▄▄▅████████████████</td></tr><tr><td>eval/runtime</td><td>▃▄▃▂▁▂▁▁▄█▃▁▁▁▁▁▂▁▃▄▁▁▃▃</td></tr><tr><td>eval/samples_per_second</td><td>▅▅▅▇█▇██▅▁▆█████▇█▆▅▇█▆▆</td></tr><tr><td>eval/steps_per_second</td><td>▅▅▅▇█▇██▅▁▆█████▇█▆▅██▆▆</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/grad_norm</td><td>▄▆█▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>██▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▁▁</td></tr><tr><td>train/loss</td><td>█▆▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.4</td></tr><tr><td>eval/loss</td><td>9.81847</td></tr><tr><td>eval/runtime</td><td>7.4439</td></tr><tr><td>eval/samples_per_second</td><td>1.343</td></tr><tr><td>eval/steps_per_second</td><td>0.134</td></tr><tr><td>total_flos</td><td>2.67132927430656e+18</td></tr><tr><td>train/epoch</td><td>40</td></tr><tr><td>train/global_step</td><td>240</td></tr><tr><td>train/grad_norm</td><td>0.03036</td></tr><tr><td>train/learning_rate</td><td>0</td></tr><tr><td>train/loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.05866</td></tr><tr><td>train_runtime</td><td>2774.4529</td></tr><tr><td>train_samples_per_second</td><td>1.225</td></tr><tr><td>train_steps_per_second</td><td>0.087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivit-b-16x2-training-iqm-filtered</strong> at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/1k1064eq' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/1k1064eq</a><br> View project at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250205_161149-1k1064eq/logs</code>

# %%
trainer.save_model("model")
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# ***** train metrics *****
#   epoch                    =         40.0
#   total_flos               = 2487869257GF
#   train_loss               =       0.0587
#   train_runtime            =   0:46:14.45
#   train_samples_per_second =        1.225
#   train_steps_per_second   =        0.087

# %%
custom_path = "./model"

# %%
TRAINED_MODEL_NAME = "Duke-ViViT-Fine-tuned-iqm-filtered-1"
with wandb.init(project=PROJECT,name="upload-duke-vivit-iqm-filtered-model-1", job_type="models"):
  artifact = wandb.Artifact(TRAINED_MODEL_NAME, type="model")
  artifact.add_dir(custom_path)
  wandb.save(custom_path)
  wandb.log_artifact(artifact)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>/home/shaunliew/ai-laryngeal-video-based-classifier/wandb/run-20250205_170712-7hkmqyes</code>
# Syncing run <strong><a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/7hkmqyes' target="_blank">upload-duke-vivit-iqm-filtered-model-1</a></strong> to <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a>
#  View run at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/7hkmqyes' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/7hkmqyes</a>
# wandb: Adding directory to artifact (./model)... Done. 1.3s
#  View run <strong style="color:#cdcd00">upload-duke-vivit-iqm-filtered-model-1</strong> at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/7hkmqyes' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/7hkmqyes</a><br> View project at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a><br>Synced 5 W&B file(s), 0 media file(s), 5 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20250205_170712-7hkmqyes/logs</code>

# %% [markdown]
# # Inference

# %%
path_files_val = "/home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0081_processed.mp4 number of Frames: 19
# Reading frames from 1 to 10
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0224_processed.mp4 number of Frames: 459
# Reading frames from 217 to 226
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0039_processed.mp4 number of Frames: 27
# Reading frames from 11 to 20
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0128_processed.mp4 number of Frames: 5
# Error processing /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0128_processed.mp4: low >= high
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0098_processed.mp4 number of Frames: 1
# Error processing /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0098_processed.mp4: low >= high
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0047_processed.mp4 number of Frames: 24
# Reading frames from 1 to 10
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0201_processed.mp4 number of Frames: 7
# Error processing /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0201_processed.mp4: low >= high
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0088_processed.mp4 number of Frames: 168
# Reading frames from 13 to 22
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0094_processed.mp4 number of Frames: 61
# Reading frames from 30 to 39
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0153_processed.mp4 number of Frames: 116
# Reading frames from 47 to 56
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0220_processed.mp4 number of Frames: 16
# Reading frames from 5 to 14
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0168_processed.mp4 number of Frames: 15
# Reading frames from 3 to 12
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0124_processed.mp4 number of Frames: 68
# Reading frames from 56 to 65
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/referral/0149_processed.mp4 number of Frames: 240
# Reading frames from 189 to 198
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0151_processed.mp4 number of Frames: 7
# Error processing /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0151_processed.mp4: low >= high
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0180_processed.mp4 number of Frames: 195
# Reading frames from 39 to 48
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0150_processed.mp4 number of Frames: 627
# Reading frames from 337 to 346
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0223_processed.mp4 number of Frames: 2
# Error processing /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0223_processed.mp4: low >= high
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0146_processed.mp4 number of Frames: 20
# Reading frames from 4 to 13
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_iqm_filtered:v0/dataset/val/non_referral/0031_processed.mp4 number of Frames: 459
# Reading frames from 279 to 288
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# Min number frames 12

# %%
val_dataset = create_dataset(video_dict_val)
# Out:
# Casting to class labels: 100%|██████████| 95/95 [00:00<00:00, 351.91 examples/s]
# Processing videos: 100%|██████████| 95/95 [02:51<00:00,  1.80s/ examples]
# First sample structure:
# Keys: dict_keys(['labels', 'split', 'path', 'pixel_values'])
# Pixel values type: <class 'list'>

# %%
import wandb
MODEL_ARTIFACT_NAME = "laryngeal_cancer_video_classification/Duke-ViViT-Fine-tuned-iqm-filtered-1:v0"
run = wandb.init(
    project=PROJECT,
    name="duke-vivit-fine-tuned -iqm-filtered-inference-1", # runs process name
    tags=[MODEL_NAME, DATASET],
    entity="shaunliewsmu-singapore-management-university"
)
artifact = run.use_artifact(MODEL_ARTIFACT_NAME, type='model')
artifact_dir = artifact.download()
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>/home/shaunliew/ai-laryngeal-video-based-classifier/wandb/run-20250205_171340-ylr7zgbe</code>
# Syncing run <strong><a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/ylr7zgbe' target="_blank">duke-vivit-fine-tuned -iqm-filtered-inference-1</a></strong> to <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a>
#  View run at <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/ylr7zgbe' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/ylr7zgbe</a>
# wandb: Downloading large artifact Duke-ViViT-Fine-tuned-iqm-filtered-1:v0, 345.65MB. 4 files...
# wandb:   4 of 4 files downloaded.
# Done. 0:0:0.7

# %%
artifact_dir
# Out:
# '/home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/Duke-ViViT-Fine-tuned-iqm-filtered-1:v0'

# %%
val_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'split', 'path', 'pixel_values'],
#         num_rows: 85
#     })
#     test: Dataset({
#         features: ['labels', 'split', 'path', 'pixel_values'],
#         num_rows: 10
#     })
# })

# %%
from data_handling import generate_all_files
import os
import numpy as np
import av
from pathlib import Path
def read_video_pyav(container, indices):
    '''
    Decode the video with PyAV decoder.
    Args:
        container (`av.container.input.InputContainer`): PyAV container.
        indices (`List[int]`): List of frame indices to decode.
    Returns:
        result (np.ndarray): np array of decoded frames of shape (num_frames, height, width, 3).
    '''
    frames = []
    container.seek(0)
    start_index = indices[0]
    end_index = indices[-1]
    for i, frame in enumerate(container.decode(video=0)):
        if i > end_index:
            break
        if i >= start_index and i in indices:
            frames.append(frame)
    return np.stack([x.to_ndarray(format="rgb24") for x in frames])


def sample_frame_indices(clip_len, frame_sample_rate, seg_len):
    '''
    Sample a given number of frame indices from the video.
    Args:
        clip_len (`int`): Total number of frames to sample.
        frame_sample_rate (`int`): Sample every n-th frame.
        seg_len (`int`): Maximum allowed index of sample's last frame.
    Returns:
        indices (`List[int]`): List of sampled frame indices
    '''
    converted_len = int(clip_len * frame_sample_rate)
    end_idx = np.random.randint(converted_len, seg_len)
    start_idx = end_idx - converted_len
    indices = np.linspace(start_idx, end_idx, num=clip_len)
    indices = np.clip(indices, start_idx, end_idx - 1).astype(np.int64)
    return indices

# %%
from transformers import VivitConfig
labels = val_dataset['train'].features['labels'].names
config = VivitConfig.from_pretrained(artifact_dir)
config.num_classes=len(labels)
config.id2label = {str(i): c for i, c in enumerate(labels)}
config.label2id = {c: str(i) for i, c in enumerate(labels)}
config.num_frames=10
config.video_size= [10, 224, 224]

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
from transformers import VivitImageProcessor, VivitForVideoClassification

# %%
image_processor = VivitImageProcessor.from_pretrained("google/vivit-b-16x2-kinetics400")
fine_tune_model = VivitForVideoClassification.from_pretrained(artifact_dir,config=config)

# %%
from pathlib import Path
import os
import av
import torch
from data_handling import sample_frame_indices, read_video_pyav, generate_all_files

# %% [markdown]
# # inference the fine-tuned model using validation set

# %%
base_dir = Path("/home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val")

# %%
# Initialize empty lists
class_labels = []
true_labels = []
predictions = []
predictions_labels = []
all_videos = []
video_files = []
sizes = []
# Iterate through files
for file_path in generate_all_files(base_dir, only_files=True):
    # Only process video files
    if not str(file_path).endswith('.mp4'):
        continue
        
    try:
        # Get dataset split and class from path
        split = file_path.parent.parent.name  # train or test
        cls = file_path.parent.name  # class name
        
        # Process class labels
        if cls not in class_labels:
            class_labels.append(cls)
        
        true_labels.append(cls)
        
        print(f"Processing file: {file_path}")
        
        # Open and process video
        container = av.open(str(file_path))
        num_frames = container.streams.video[0].frames
        
        indices = sample_frame_indices(
            clip_len=10, 
            frame_sample_rate=1,
            seg_len=num_frames
        )
        
        video = read_video_pyav(container=container, indices=indices)
        inputs = image_processor(list(video), return_tensors="pt")
        
        # Get model predictions
        with torch.no_grad():
            outputs = fine_tune_model(**inputs)
            logits = outputs.logits
            
        predicted_label = logits.argmax(-1).item()
        prediction = fine_tune_model.config.id2label[str(predicted_label)]
        
        predictions.append(prediction)
        predictions_labels.append(predicted_label)
        
        print(f"File: {file_path.name}")
        print(f"True Label: {cls}")
        print(f"Predicted Label: {prediction}")
        print("-" * 50)
        
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        continue
    finally:
        if 'container' in locals():
            container.close()

print("\nProcessing complete!")
print(f"Total videos processed: {len(predictions)}")
print(f"Unique classes found: {len(class_labels)}")
# Out:
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0224.mp4
# Reading frames from 763 to 772
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0224.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0220.mp4
# Reading frames from 2235 to 2244
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0220.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0124.mp4
# Reading frames from 379 to 388
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0124.mp4
# True Label: referral
# Predicted Label: non_referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0088.mp4
# Reading frames from 492 to 501
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0088.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0047.mp4
# Reading frames from 14 to 23
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0047.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0128.mp4
# Reading frames from 64 to 73
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0128.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0201.mp4
# Reading frames from 520 to 529
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0201.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0039.mp4
# Reading frames from 343 to 352
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0039.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0081.mp4
# Reading frames from 1152 to 1161
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0081.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0094.mp4
# Reading frames from 647 to 656
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0094.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0153.mp4
# Reading frames from 471 to 480
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0153.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0168.mp4
# Reading frames from 1086 to 1095
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0168.mp4
# True Label: referral
# Predicted Label: non_referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0098.mp4
# Reading frames from 1162 to 1171
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0098.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0149.mp4
# Reading frames from 1522 to 1531
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0149.mp4
# True Label: referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0223.mp4
# Reading frames from 592 to 601
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0223.mp4
# True Label: non_referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0031.mp4
# Reading frames from 391 to 400
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0031.mp4
# True Label: non_referral
# Predicted Label: non_referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0146.mp4
# Reading frames from 1698 to 1707
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0146.mp4
# True Label: non_referral
# Predicted Label: non_referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0151.mp4
# Reading frames from 418 to 427
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0151.mp4
# True Label: non_referral
# Predicted Label: non_referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0150.mp4
# Reading frames from 288 to 297
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0150.mp4
# True Label: non_referral
# Predicted Label: referral
# --------------------------------------------------
# Processing file: /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/non_referral/0180.mp4
# Reading frames from 378 to 387
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)
# File: 0180.mp4
# True Label: non_referral
# Predicted Label: non_referral
# --------------------------------------------------
#
# Processing complete!
# Total videos processed: 20
# Unique classes found: 2

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(true_labels, predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# non_referral       0.67      0.67      0.67         6
#     referral       0.86      0.86      0.86        14
#
#     accuracy                           0.80        20
#    macro avg       0.76      0.76      0.76        20
# weighted avg       0.80      0.80      0.80        20

# %% [markdown]
# # inference using one video sample

# %%
file_name = "/home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0039.mp4"
container = av.open(file_name)

# %%
indices = sample_frame_indices(clip_len=10, frame_sample_rate=3,seg_len=container.streams.video[0].frames)
print(f"Processing file {file_name} number of Frames: {container.streams.video[0].frames}")  
video = read_video_pyav(container=container, indices=indices)
inputs = image_processor(list(video), return_tensors="pt")
# Out:
# Processing file /home/shaunliew/ai-laryngeal-video-based-classifier/artifacts/laryngeal_dataset_balanced:v0/dataset/val/referral/0039.mp4 number of Frames: 600
# Reading frames from 489 to 518
# Number of frames extracted: 10
# Final video array shape: (10, 224, 224, 3)

# %%
with torch.no_grad():
    outputs = fine_tune_model(**inputs)
    logits = outputs.logits

# %%
predicted_label = logits.argmax(-1).item()
prediction = fine_tune_model.config.id2label[str(predicted_label)]
prediction
# Out:
# 'referral'

# %%
# close the wandb run
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">duke-vivit-fine-tuned -iqm-filtered-inference-1</strong> at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/ylr7zgbe' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification/runs/ylr7zgbe</a><br> View project at: <a href='https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification' target="_blank">https://wandb.ai/shaunliewsmu-singapore-management-university/laryngeal_cancer_video_classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250205_171340-ylr7zgbe/logs</code>
